# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
#   # Answer 1

# %%
users = pd.read_csv('E:/Studies/Classes/Sem1/Data Programming(1004)/Class/Assignment/Assignment3/data1.csv')

# %%
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator     2215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# Step4

# %%
users[["occupation", "age"]].groupby("occupation").mean()
# Out:
#                      age
# occupation
# administrator  38.746835
# artist         31.392857
# doctor         43.571429
# educator       42.010526
# engineer       36.388060
# entertainment  29.222222
# executive      38.718750
# healthcare     41.562500
# homemaker      32.571429
# lawyer         36.750000
# librarian      40.000000
# marketing      37.615385
# none           26.555556
# other          34.523810
# programmer     33.121212
# retired        63.071429
# salesman       35.666667
# scientist      35.548387
# student        22.081633
# technician     33.148148
# writer         36.311111

# %% [markdown]
# Step5

# %%
df1=users.groupby(["occupation","gender"])["gender"].count()/users.groupby(["occupation"])["gender"].count()

# %%
df2=df1.unstack(level=-1)

# %%
df3=df2.filter(items=['gender','M']);

# %%
df3.sort_values(by='M',ascending=False)
# Out:
# gender                M
# occupation
# doctor         1.000000
# engineer       0.970149
# technician     0.962963
# retired        0.928571
# programmer     0.909091
# executive      0.906250
# scientist      0.903226
# entertainment  0.888889
# lawyer         0.833333
# salesman       0.750000
# educator       0.726316
# student        0.693878
# other          0.657143
# marketing      0.615385
# writer         0.577778
# none           0.555556
# administrator  0.544304
# artist         0.535714
# librarian      0.431373
# healthcare     0.312500
# homemaker      0.142857

# %% [markdown]
# Step6

# %%
users.groupby(['occupation'])['age'].max()
# Out:
# occupation
# administrator    70
# artist           48
# doctor           64
# educator         63
# engineer         70
# entertainment    50
# executive        69
# healthcare       62
# homemaker        50
# lawyer           53
# librarian        69
# marketing        55
# none             55
# other            64
# programmer       63
# retired          73
# salesman         66
# scientist        55
# student          42
# technician       55
# writer           60
# Name: age, dtype: int64

# %%
users.groupby(['occupation'])['age'].min()
# Out:
# occupation
# administrator    21
# artist           19
# doctor           28
# educator         23
# engineer         22
# entertainment    15
# executive        22
# healthcare       22
# homemaker        20
# lawyer           21
# librarian        23
# marketing        24
# none             11
# other            13
# programmer       20
# retired          51
# salesman         18
# scientist        23
# student           7
# technician       21
# writer           18
# Name: age, dtype: int64

# %% [markdown]
# Step7

# %%
users.groupby(['occupation','gender'])['age'].mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
Step8

# %%
users.groupby(["occupation","gender"])["gender"].count()/users.groupby(["occupation"])["gender"].count()
# Out:
# occupation     gender
# administrator  F         0.455696
#                M         0.544304
# artist         F         0.464286
#                M         0.535714
# doctor         M         1.000000
# educator       F         0.273684
#                M         0.726316
# engineer       F         0.029851
#                M         0.970149
# entertainment  F         0.111111
#                M         0.888889
# executive      F         0.093750
#                M         0.906250
# healthcare     F         0.687500
#                M         0.312500
# homemaker      F         0.857143
#                M         0.142857
# lawyer         F         0.166667
#                M         0.833333
# librarian      F         0.568627
#                M         0.431373
# marketing      F         0.384615
#                M         0.615385
# none           F         0.444444
#                M         0.555556
# other          F         0.342857
#                M         0.657143
# ...

# %% [markdown]
# # answer 2

# %%
euro12 = pd.read_csv('E:/Studies/Classes/Sem1/Data Programming(1004)/Class/Assignment/Assignment3/data2.csv')

# %% [markdown]
# Step4

# %%
f1=euro12.filter(items=['Goals']);

# %%
f1
# Out:
#     Goals
# 0       4
# 1       4
# 2       4
# 3       5
# 4       3
# 5      10
# 6       5
# 7       6
# 8       2
# 9       2
# 10      6
# 11      1
# 12      5
# 13     12
# 14      5
# 15      2

# %% [markdown]
# Step5

# %%
euro12.Team.count()
# Out:
# 16

# %% [markdown]
# Step6

# %%
len(euro12.columns)
# Out:
# 35

# %% [markdown]
# Step7

# %%
discipline=euro12[['Team','Yellow Cards','Red Cards']]

# %%
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# Step8

# %%
discipline.sort_values(['Red Cards','Yellow Cards'])
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1

# %% [markdown]
# Step9

# %%
discipline.groupby(['Team'])['Yellow Cards'].mean()
# Out:
# Team
# Croatia                 9
# Czech Republic          7
# Denmark                 4
# England                 5
# France                  6
# Germany                 4
# Greece                  9
# Italy                  16
# Netherlands             5
# Poland                  7
# Portugal               12
# Republic of Ireland     6
# Russia                  6
# Spain                  11
# Sweden                  7
# Ukraine                 5
# Name: Yellow Cards, dtype: int64

# %%
Step10

# %%
euro12[(euro12.Goals > 6)]
# Out:
#        Team  Goals  Shots on target  Shots off target  Shooting Accuracy  \
# 5   Germany     10               32                32              0.478
# 13    Spain     12               42                33              0.559
#
#     % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5              0.156                          80             2              1
# 13             0.160                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 0.626         63
# 13                     0  ...          15                 0.938        102
#
#     Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5               49        12             4          0       15        15
# 13              83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %% [markdown]
# Step11

# %%
euro12[euro12['Team'].str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target  Shooting Accuracy  \
# 5  Germany     10               32                32              0.478
# 6   Greece      5                8                18              0.307
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             0.156                          80             2              1
# 6             0.192                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 0.626         63
# 6                     1  ...          13                 0.651         67
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 6              48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# ...

# %% [markdown]
# Step12

# %%
euro12.head(7)
# Out:
#              Team  Goals  Shots on target  Shots off target  \
# 0         Croatia      4               13                12
# 1  Czech Republic      4               13                18
# 2         Denmark      4               10                10
# 3         England      5               11                18
# 4          France      3               22                24
# 5         Germany     10               32                32
# 6          Greece      5                8                18
#
#    Shooting Accuracy  % Goals-to-shots  Total shots (inc. Blocked)  \
# 0              0.519             0.160                          32
# 1              0.419             0.129                          39
# 2              0.500             0.200                          27
# 3              0.500             0.172                          40
# 4              0.379             0.065                          65
# 5              0.478             0.156                          80
# ...

# %%
Step13

# %%
euro12.tail(3)
# Out:
#        Team  Goals  Shots on target  Shots off target  Shooting Accuracy  \
# 13    Spain     12               42                33              0.559
# 14   Sweden      5               17                19              0.472
# 15  Ukraine      2                7                26              0.212
#
#     % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 13             0.160                         100             0              1
# 14             0.138                          39             3              0
# 15             0.060                          38             0              0
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 13                     0  ...          15                 0.938        102
# 14                     0  ...           8                 0.616         35
# 15                     0  ...          13                 0.765         48
#
# ...

# %% [markdown]
# Step14

# %%
euro_team = euro12.loc[(euro12.Team == 'Russia') | (euro12.Team == 'England') | (euro12.Team == 'Italy')]

# %%
euro_team['Shooting Accuracy']
# Out:
# 3     0.500
# 7     0.430
# 12    0.225
# Name: Shooting Accuracy, dtype: float64

# %% [markdown]
# # Answer 3

# %%
import random

# %% [markdown]
# Step2

# %%
randomlist1 = pd.Series(np.random.randint(1,5,100))
randomlist2 = pd.Series(np.random.randint(1,4,100))                        
randomlist3 = pd.Series(np.random.randint(10000,30000,100))

# %% [markdown]
# Step3 & Step 4

# %%
data={"bedrs": randomlist1,
        "bathrs": randomlist2,
        "price_sqr_meter": randomlist3}

# %%
df = pd.concat(data,
               axis = 1)

# %%
df
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       2       3            29627
# 1       1       3            13569
# 2       4       3            13505
# 3       2       2            25970
# 4       2       3            23922
# ..    ...     ...              ...
# 95      1       1            10257
# 96      2       1            13017
# 97      3       1            21118
# 98      3       1            26296
# 99      1       1            26578
#
# [100 rows x 3 columns]

# %% [markdown]
# Step 5

# %%
big_columns = pd.DataFrame(pd.concat([randomlist1,randomlist2,randomlist3],axis=0),columns=['big_column'])

# %% [markdown]
# Step 6

# %%
big_columns
# Out:
#     big_column
# 0            2
# 1            1
# 2            4
# 3            2
# 4            2
# ..         ...
# 95       10257
# 96       13017
# 97       21118
# 98       26296
# 99       26578
#
# [300 rows x 1 columns]

# %% [markdown]
# Step 7

# %%
big_columns.reset_index(inplace=True)

# %%
big_columns
# Out:
#      index  big_column
# 0        0           2
# 1        1           1
# 2        2           4
# 3        3           2
# 4        4           2
# ..     ...         ...
# 295     95       10257
# 296     96       13017
# 297     97       21118
# 298     98       26296
# 299     99       26578
#
# [300 rows x 2 columns]

# %% [markdown]
# # Answer 4

# %%
data = pd.read_csv('E:/Studies/Classes/Sem1/Data Programming(1004)/Class/Assignment/Assignment3/data4.csv')

# %% [markdown]
# Step3 ,4 &5

# %%
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %%
data['Yr']=data['Yr'].astype('string')
data['Mo']=data['Mo'].astype('string')
data['Dy']=data['Dy'].astype('string')
data['Datetime'] = pd.to_datetime(data['Yr']+data['Mo'].str.pad(2,fillchar='0')+data['Dy'].str.pad(2,fillchar='0'),format='%y%m%d')

# %%
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL   Datetime
# 0     10.83  12.58  18.50  15.04 2061-01-01
# ...

# %% [markdown]
# No,it is not and from different year

# %%
from pandas import datetime 
def parser(x):
	return datetime.strptime('19'+x, '%Y%m%d')
# Out:
# <ipython-input-109-57ea437f7b54>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
data['dateInt']=data['Yr'].astype(str) + data['Mo'].astype(str).str.zfill(2)+ data['Dy'].astype(str).str.zfill(2)

# %%
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL   Datetime    dataInt dateInt
# ...

# %%
data['Datetime1']=data['dateInt'].apply(parser)

# %%
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL   Datetime    dataInt dateInt  Datetime1
# ...

# %% [markdown]
# Step6

# %%
data.isna().sum()
# Out:
# Yr          0
# Mo          0
# Dy          0
# RPT         6
# VAL         3
# ROS         2
# KIL         5
# SHA         2
# BIR         0
# DUB         3
# CLA         2
# MUL         3
# CLO         1
# BEL         0
# MAL         4
# Datetime    0
# dtype: int64

# %% [markdown]
# STEP7

# %%
data.isnull().sum().sum()
# Out:
# 31

# %% [markdown]
# Step8

# %%
data.mean().mean()
# Out:
# <ipython-input-32-e9c1cd44013d>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data.mean().mean()
# 14.299199599246556

# %% [markdown]
# Step9

# %%
locs_stats = data.agg(['mean', 'min', 'max','std'])

# %%
locs_stats
# Out:
#              Yr         Mo         Dy        RPT        VAL        ROS  \
# mean  69.500304   6.523274  15.728628  12.362987  10.644314  11.660526
# min   61.000000   1.000000   1.000000   0.670000   0.210000   1.500000
# max   78.000000  12.000000  31.000000  35.800000  33.370000  33.840000
# std    5.188131   3.448871   8.800335   5.618413   5.267356   5.008450
#
#             KIL        SHA        BIR        DUB        CLA        MUL  \
# mean   6.306468  10.455834   7.092254   9.797343   8.495053   8.493590
# min    0.000000   0.130000   0.000000   0.000000   0.000000   0.000000
# max   28.460000  37.540000  26.160000  30.370000  31.080000  25.880000
# std    3.605811   4.936125   3.968683   4.977555   4.499449   4.166872
#
#             CLO        BEL        MAL                      Datetime
# mean   8.707332  13.121007  15.599079 1970-01-01 00:00:00.000000091
# min    0.040000   0.130000   0.670000 1970-01-01 00:00:00.000000063
# ...

# %% [markdown]
# Step10

# %%
date_stats = data.groupby('Dy').agg({'RPT': ['mean', 'min', 'max','std'],'VAL': ['mean', 'min', 'max','std'],'ROS': ['mean', 'min', 'max','std'],'KIL': ['mean', 'min', 'max','std'],'SHA': ['mean', 'min', 'max','std'],'BIR': ['mean', 'min', 'max','std'],'DUB': ['mean', 'min', 'max','std'],'CLA': ['mean', 'min', 'max','std'],'MUL': ['mean', 'min', 'max','std'],'CLO': ['mean', 'min', 'max','std'],'BEL': ['mean', 'min', 'max','std'],'MAL': ['mean', 'min', 'max','std']})

# %%
date_stats
# Out:
#           RPT                               VAL                         \
#          mean   min    max       std       mean   min    max       std
# Dy
# 1   12.787037  3.42  34.37  5.534959  10.930741  0.79  33.37  5.412796
# 2   12.726713  2.62  33.84  5.946406  10.843953  0.54  28.50  5.572061
# 3   12.264028  2.00  26.30  4.838973  10.254537  0.67  24.87  4.848868
# 4   11.644651  1.21  29.04  5.482379  10.168657  0.71  27.58  4.988027
# 5   11.770972  2.67  28.33  5.018858  10.283750  0.75  22.79  4.575625
# 6   12.353333  2.37  29.33  5.736093  10.603981  0.96  23.87  5.440491
# 7   12.508519  1.50  35.80  5.991000  10.801806  0.42  31.63  5.412942
# 8   12.023935  2.29  32.58  5.355591  10.345046  0.67  24.00  4.946410
# 9   12.517870  2.21  31.42  5.428632  10.818981  0.83  28.50  5.403010
# 10  12.755370  3.33  33.84  5.933813  11.038009  1.38  27.04  5.791016
# 11  13.002605  1.96  30.84  5.759974  11.008287  1.87  30.96  5.472212
# ...

# %% [markdown]
# Step11

# %%
Mon_stats = data.groupby('Mo').agg({'RPT': ['mean'],'VAL': ['mean'],'ROS': ['mean'],'KIL': ['mean'],'SHA': ['mean'],'BIR': ['mean'],'DUB': ['mean'],'CLA': ['mean'],'MUL': ['mean'],'CLO': ['mean'],'BEL': ['mean'],'MAL': ['mean']})

# %%
Mon_stats.query('Mo == 1')
# Out:
#           RPT       VAL        ROS       KIL        SHA       BIR        DUB  \
#          mean      mean       mean      mean       mean      mean       mean
# Mo
# 1   14.847325  12.91456  13.299624  7.199498  11.667734  8.054839  11.819355
#
#          CLA       MUL        CLO       BEL        MAL
#         mean      mean       mean      mean       mean
# Mo
# 1   9.512047  9.543208  10.053566  14.55052  18.028763

# %%
data.index=data['Datetime1']

# %% [markdown]
# Step12

# %%
data.groupby(data.index.to_period('Y')).mean()
# Out:
#                  RPT        VAL        ROS       KIL        SHA       BIR  \
# Datetime1
# 1961       12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962       12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963       12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964       12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965       12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966       13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967       12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968       11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969       11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970       12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971       11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# ...

# %% [markdown]
# Step 13

# %%
data.groupby(data.index.to_period('M')).mean()
# Out:
#                  RPT        VAL        ROS       KIL        SHA        BIR  \
# Datetime1
# 1961-01    14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02    16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03    10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04    10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05     9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...              ...        ...        ...       ...        ...        ...
# 1978-08     9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09    10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10     9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11    16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12    16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %% [markdown]
# Step 14

# %%
data_w=data.groupby(data.index.to_period('W')).mean()

# %% [markdown]
# Step 15

# %%
data_w1=data_w.iloc[1:53]

# %%
data_w1.agg(['mean', 'min', 'max','std'])
# Out:
#             RPT        VAL        ROS        KIL        SHA        BIR  \
# mean  12.289130  10.332060  11.347326   6.946740  10.876502   7.723846
# min    4.202857   4.255714   6.738571   3.300000   6.112857   2.715714
# max   19.880000  16.417143  18.225714  12.720000  17.432857  14.828571
# std    3.402637   2.831028   2.847221   2.067368   2.677186   2.431632
#
#             DUB        CLA        MUL        CLO        BEL        MAL
# mean   9.730810   8.843375   8.653617   9.820893  13.489066  13.681625
# min    3.964286   4.257143   4.501429   6.031429   5.875714   5.737143
# max   15.565714  15.160000  14.480000  16.461429  21.832857  23.641429
# std    2.812689   2.456673   2.409221   2.585514   3.615946   3.580699

# %% [markdown]
# # Answer5

# %% [markdown]
# Step 2 &3

# %%
Chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',delimiter='\t');

# %% [markdown]
# Step 4

# %%
Chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# Step 5

# %%
len(Chipo.index)
# Out:
# 4622

# %% [markdown]
# Step 6

# %%
len(Chipo.columns)
# Out:
# 5

# %% [markdown]
# Step 7

# %%
Chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# Step 8

# %%
Chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# Step 9

# %%
Chipo['item_name'].value_counts().idxmax()
# Out:
# 'Chicken Bowl'

# %% [markdown]
# Step 10

# %%
Chipo['item_name'].value_counts().max()
# Out:
# 726

# %% [markdown]
# Step 11

# %%
Chipo['choice_description'].value_counts().idxmax()
# Out:
# '[Diet Coke]'

# %% [markdown]
# Step 12

# %%
Chipo.count()
# Out:
# order_id              4622
# quantity              4622
# item_name             4622
# choice_description    3376
# item_price            4622
# dtype: int64

# %% [markdown]
# Step13

# %%
Chipo["item_price"]=Chipo[Chipo.columns[4]].replace('[\$,]', '', regex=True).astype(float)

# %%
Chipo.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
Chipo.apply(lambda x : pd.to_numeric(Chipo["item_price"], errors='coerce', downcast="float"))
# Out:
#       order_id  quantity  item_name  choice_description  item_price
# 0         2.39      2.39       2.39                2.39        2.39
# 1         3.39      3.39       3.39                3.39        3.39
# 2         3.39      3.39       3.39                3.39        3.39
# 3         2.39      2.39       2.39                2.39        2.39
# 4        16.98     16.98      16.98               16.98       16.98
# ...        ...       ...        ...                 ...         ...
# 4617     11.75     11.75      11.75               11.75       11.75
# 4618     11.75     11.75      11.75               11.75       11.75
# 4619     11.25     11.25      11.25               11.25       11.25
# 4620      8.75      8.75       8.75                8.75        8.75
# 4621      8.75      8.75       8.75                8.75        8.75
#
# [4622 rows x 5 columns]

# %%
Chipo.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
Chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %% [markdown]
# Step14

# %%
Chipo.sum()
# Out:
# order_id                                                4285772
# quantity                                                   4972
# item_name     Chips and Fresh Tomato SalsaIzzeNantucket Nect...
# item_price                                              34500.2
# dtype: object

# %% [markdown]
# 34500

# %% [markdown]
# Step 15

# %%
Chipo.count()
# Out:
# order_id              4622
# quantity              4622
# item_name             4622
# choice_description    3376
# item_price            4622
# dtype: int64

# %% [markdown]
# 4622

# %% [markdown]
# Step 16

# %%
Chipo.mean()
# Out:
# order_id      927.254868
# quantity        1.075725
# item_price      7.464336
# dtype: float64

# %% [markdown]
# 7.464336

# %% [markdown]
# Step 17

# %%
len(pd.unique(Chipo['item_name']))
# Out:
# 50

# %% [markdown]
# # Answer6

# %%
import pandas as pd

# %%
data_6=pd.read_csv('E:/Studies/Classes/Sem1/Data Programming(1004)/Class/Assignment/Assignment3/us-marriages-divorces-1867-20146_6_7.csv')

# %%
marriage=pd.read_csv('E:/Studies/Classes/Sem1/Data Programming(1004)/Class/Assignment/Assignment3/us-marriages-divorces-1867-20146_6_7.csv')

# %%
data_6
# Out:
#      Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0    1867   357000.0   10000.0    36970000                 9.7
# 1    1868   345000.0   10000.0    37885000                 9.1
# 2    1869   348000.0   11000.0    38870000                 9.0
# 3    1870   352000.0   11000.0    39905000                 8.8
# 4    1871   359000.0   12000.0    41010000                 8.8
# ..    ...        ...       ...         ...                 ...
# 140  2007  2197000.0  856000.0   301696000                 7.3
# 141  2008  2157000.0  844000.0   304543000                 7.1
# 142  2009  2080000.0  840000.0   307240000                 6.8
# 143  2010  2096000.0  872000.0   309776000                 6.8
# 144  2011  2118000.0  877000.0   312034000                 6.8
#
#      Divorces_per_1000
# 0                  0.3
# 1                  0.3
# 2                  0.3
# 3                  0.3
# 4                  0.3
# ..                 ...
# 140                2.8
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data_6['Year'], data_6['Marriages'],color='green' )
plt.plot(data_6['Year'], data_6['Divorces'],color='red' )
plt.title('Number of divorces & Marriages Vs Year')
plt.xlabel('Year')
plt.ylabel('Number of divorces & Marriages')
plt.show()

# %% [markdown]
# # Answer7

# %%
data_bar=data_6[(data_6.Year == 1900)|(data_6.Year == 1950)|(data_6.Year == 2000)]

# %%
data_1=data_bar.filter(items=['Year','Marriages_per_1000','Divorces_per_1000']);

# %%
ax=data_1.plot('Year',['Marriages_per_1000','Divorces_per_1000'],kind='bar')

# %% [markdown]
# # Answer8

# %%
data_8=pd.read_csv('E:/Studies/Classes/Sem1/Data Programming(1004)/Class/Assignment/Assignment3/actor_kill_counts_8.csv')

# %%
data_8
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 2         Clint Eastwood    207
# 3             Clive Owen    194
# 4         Dolph Lundgren    239
# 5                 Jet Li    201
# 6           Nicolas Cage    204
# 7     Sylvester Stallone    267
# 8    Tomisaburo Wakayama    226
# 9          Wesley Snipes    193

# %%
dataF=data_8.sort_values(by='Count')

# %%
Actor=dataF['Actor']
Kills=dataF['Count']
plt.barh(Actor,Kills)
plt.title('Number of kills by Actor')
plt.ylabel('Actor')
plt.xlabel('Kills')
plt.show()

# %% [markdown]
# # Answer9

# %%
data_9=pd.read_csv('E:/Studies/Classes/Sem1/Data Programming(1004)/Class/Assignment/Assignment3/roman-emperor-reigns_9.csv')

# %%
data_9
# Out:
#            Emperor  Length_of_Reign         Cause_of_Death
# 0         Augustus            40.58  Possibly assassinated
# 1         Tiberius            22.50  Possibly assassinated
# 2         Caligula             4.83           Assassinated
# 3         Claudius            13.75  Possibly assassinated
# 4             Nero            13.67                Suicide
# ..             ...              ...                    ...
# 63   Valentinian I            11.00         Natural causes
# 64          Valens            14.00       Killed in battle
# 65         Gratian            16.00           Assassinated
# 66  Valentinian II            17.00  Possibly assassinated
# 67    Theodosius I            16.00         Natural causes
#
# [68 rows x 3 columns]

# %%
data9=data_9[(data_9.Cause_of_Death=='Assassinated')]

# %%
data9
# Out:
#                Emperor  Length_of_Reign Cause_of_Death
# 2             Caligula             4.83   Assassinated
# 5                Galba             0.58   Assassinated
# 7            Vitellius             0.67   Assassinated
# 10            Domitian            15.00   Assassinated
# 17            Commodus            15.00   Assassinated
# 18            Pertinax             0.25   Assassinated
# 21           Caracalla            19.00   Assassinated
# 22                Geta             3.00   Assassinated
# 24          Elagabalus             3.75   Assassinated
# 25   Severus Alexander            13.00   Assassinated
# 26         Maximinus I             3.25   Assassinated
# 29            Pupienus             0.25   Assassinated
# 30            Balbinus             0.25   Assassinated
# 35  Trebonianus Gallus             2.00   Assassinated
# 36            Aemilian             0.16   Assassinated
# 38           Gallienus            15.00   Assassinated
# ...

# %%
plt.pie(data9['Length_of_Reign'],labels=data9['Emperor'],autopct='%1.1f%%')
plt.title('Length of Each Roman Emperor')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Answer10

# %%
data10 = pd.read_csv('E:/Studies/Classes/Sem1/Data Programming(1004)/Class/Assignment/Assignment3/arcade-revenue-vs-cs-doctorates.csv')

# %%
x=data10.TotalArcadeRevenue
y=data10.ComputerScienceDoctoratesAwarded
data10.plot.scatter(x = 'TotalArcadeRevenue', y = 'ComputerScienceDoctoratesAwarded')
# Out:
# <AxesSubplot:xlabel='TotalArcadeRevenue', ylabel='ComputerScienceDoctoratesAwarded'>
